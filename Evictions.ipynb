# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
# graph settings
# %matplotlib inline
matplotlib.rcParams['font.sans-serif'] = "Helvetica"
matplotlib.rcParams['font.family'] = "sans-serif"

# %%
df = pd.read_csv('Evictions.csv')

# %%
df
# Out:
#       Court Index Number  Docket Number   \
# 0               48174/18          349487
# 1              B35706/18          108013
# 2               55095/17           10840
# 3              Q72651/16           75106
# 4               64094/17           11817
# ...                  ...             ...
# 74588          315053/22          110298
# 74589           54940/16          320221
# 74590           28486/19          172082
# 74591           51564/16          328978
# 74592           66670/16          323525
#
#                             Eviction Address Eviction Apartment Number  \
# 0                        1238 BOYNTON AVENUE                        1R
# 1                       3235 GRAND CONCOURSE                        6C
# 2                          640 E 86TH STREET                       NaN
# 3                          148-41 236 STREET                       NaN
# 4                          38-32 29TH STREET                         1
# ...                                      ...                       ...
# 74588                     315 WEST 61 STREET                        8R
# 74589                   2277 BATHGATE AVENUE                        5E
# 74590                        576 PUGSLEY AVE                         1
# 74591                     1240 WALTON AVENUE                       406
# 74592  3347 MICKLE AV-1ST FL, 2ND FL, & BSMT                         1
#
#       Executed Date Marshal First Name Marshal Last Name  \
# 0        03/08/2019             Thomas               Bia
# 1        10/03/2018            Darlene            Barone
# 2        07/25/2017             Edward             Guida
# 3        03/31/2017             Ileana            Rivera
# 4        08/16/2017             Edward             Guida
# ...             ...                ...               ...
# 74588    02/22/2023              Henry             Daley
# 74589    05/02/2017               John        Villanueva
# 74590    01/31/2020             Alfred          Locascio
# 74591    02/01/2017             Thomas               Bia
# 74592    04/27/2017               John        Villanueva
#
#       Residential/Commercial    BOROUGH  Eviction Postcode         Ejectment  \
# 0                Residential      BRONX              10472  Not an Ejectment
# 1                Residential      BRONX              10468  Not an Ejectment
# 2                Residential   BROOKLYN              11236  Not an Ejectment
# 3                Residential     QUEENS              11422  Not an Ejectment
# 4                Residential     QUEENS              11101  Not an Ejectment
# ...                      ...        ...                ...               ...
# 74588            Residential  MANHATTAN              10023  Not an Ejectment
# 74589            Residential      BRONX              10457  Not an Ejectment
# 74590            Residential      BRONX              10473  Not an Ejectment
# 74591            Residential      BRONX              10452  Not an Ejectment
# 74592            Residential      BRONX              10469  Not an Ejectment
#
#       Eviction/Legal Possession   Latitude  Longitude  Community Board  \
# 0                    Possession  40.829759 -73.878482              9.0
# 1                    Possession  40.877488 -73.885258              7.0
# 2                    Possession  40.640733 -73.911547             18.0
# 3                    Possession  40.653782 -73.747053             13.0
# 4                    Possession  40.754198 -73.933916              1.0
# ...                         ...        ...        ...              ...
# 74588                Possession  40.773086 -73.990057              7.0
# 74589                Possession  40.854283 -73.892119              6.0
# 74590                Possession  40.817854 -73.854034              9.0
# 74591                Possession  40.835879 -73.918837              4.0
# 74592                Possession        NaN        NaN              NaN
#
#        Council District  Census Tract        BIN           BBL  \
# 0                  18.0          54.0  2025234.0  2.037740e+09
# 1                  11.0         411.0  2017667.0  2.033230e+09
# 2                  46.0         958.0  3223963.0  3.079900e+09
# 3                  31.0         694.0  4443919.0  4.137360e+09
# 4                  26.0          31.0  4004669.0  4.003850e+09
# ...                 ...           ...        ...           ...
# 74588               6.0         151.0  1087589.0  1.011718e+09
# 74589              15.0         385.0  2117654.0  2.030500e+09
# 74590              18.0          74.0  2088061.0  2.035330e+09
# 74591              16.0         197.0  2002852.0  2.024650e+09
# 74592               NaN           NaN        NaN           NaN
#
#                                                    NTA
# 0                               West Farms-Bronx River
# 1                           Bedford Park-Fordham North
# 2                                             Canarsie
# 3                 Springfield Gardens South-Brookville
# 4             Queensbridge-Ravenswood-Long Island City
# ...                                                ...
# 74588                                   Lincoln Square
# 74589                               Claremont-Bathgate
# 74590  Soundview-Castle Hill-Clason Point-Harding Park
# 74591                                   West Concourse
# 74592                                              NaN
#
# [74593 rows x 20 columns]

# %%
df['Executed Date'] = df['Executed Date'].apply(pd.to_datetime)

# %%
df['Marshal Full Name'] = df['Marshal First Name'] + ' ' + df['Marshal Last Name']

# %%
df = df.copy().dropna(subset=['NTA'])

# %%
df
# Out:
#       Court Index Number  Docket Number       Eviction Address  \
# 0               48174/18          349487   1238 BOYNTON AVENUE
# 1              B35706/18          108013  3235 GRAND CONCOURSE
# 2               55095/17           10840     640 E 86TH STREET
# 3              Q72651/16           75106     148-41 236 STREET
# 4               64094/17           11817     38-32 29TH STREET
# ...                  ...             ...                   ...
# 74587           87750/18           88027   2125 PACIFIC STREET
# 74588          315053/22          110298    315 WEST 61 STREET
# 74589           54940/16          320221  2277 BATHGATE AVENUE
# 74590           28486/19          172082       576 PUGSLEY AVE
# 74591           51564/16          328978    1240 WALTON AVENUE
#
#       Eviction Apartment Number Executed Date Marshal First Name  \
# 0                            1R    2019-03-08             Thomas
# 1                            6C    2018-10-03            Darlene
# 2                           NaN    2017-07-25             Edward
# 3                           NaN    2017-03-31             Ileana
# 4                             1    2017-08-16             Edward
# ...                         ...           ...                ...
# 74587                        4D    2019-10-07             Justin
# 74588                        8R    2023-02-22              Henry
# 74589                        5E    2017-05-02               John
# 74590                         1    2020-01-31             Alfred
# 74591                       406    2017-02-01             Thomas
#
#       Marshal Last Name Residential/Commercial    BOROUGH  Eviction Postcode  \
# 0                   Bia            Residential      BRONX              10472
# 1                Barone            Residential      BRONX              10468
# 2                 Guida            Residential   BROOKLYN              11236
# 3                Rivera            Residential     QUEENS              11422
# 4                 Guida            Residential     QUEENS              11101
# ...                 ...                    ...        ...                ...
# 74587          Grossman            Residential   BROOKLYN              11233
# 74588             Daley            Residential  MANHATTAN              10023
# 74589        Villanueva            Residential      BRONX              10457
# 74590          Locascio            Residential      BRONX              10473
# 74591               Bia            Residential      BRONX              10452
#
#        ... Eviction/Legal Possession   Latitude  Longitude  Community Board  \
# 0      ...                Possession  40.829759 -73.878482              9.0
# 1      ...                Possession  40.877488 -73.885258              7.0
# 2      ...                Possession  40.640733 -73.911547             18.0
# 3      ...                Possession  40.653782 -73.747053             13.0
# 4      ...                Possession  40.754198 -73.933916              1.0
# ...    ...                       ...        ...        ...              ...
# 74587  ...                Possession  40.675820 -73.916065             16.0
# 74588  ...                Possession  40.773086 -73.990057              7.0
# 74589  ...                Possession  40.854283 -73.892119              6.0
# 74590  ...                Possession  40.817854 -73.854034              9.0
# 74591  ...                Possession  40.835879 -73.918837              4.0
#
#        Council District  Census Tract        BIN           BBL  \
# 0                  18.0          54.0  2025234.0  2.037740e+09
# 1                  11.0         411.0  2017667.0  2.033230e+09
# 2                  46.0         958.0  3223963.0  3.079900e+09
# 3                  31.0         694.0  4443919.0  4.137360e+09
# 4                  26.0          31.0  4004669.0  4.003850e+09
# ...                 ...           ...        ...           ...
# 74587              41.0         303.0  3038558.0  3.014330e+09
# 74588               6.0         151.0  1087589.0  1.011718e+09
# 74589              15.0         385.0  2117654.0  2.030500e+09
# 74590              18.0          74.0  2088061.0  2.035330e+09
# 74591              16.0         197.0  2002852.0  2.024650e+09
#
#                                                    NTA Marshal Full Name
# 0                               West Farms-Bronx River        Thomas Bia
# 1                           Bedford Park-Fordham North    Darlene Barone
# 2                                             Canarsie      Edward Guida
# 3                 Springfield Gardens South-Brookville     Ileana Rivera
# 4             Queensbridge-Ravenswood-Long Island City      Edward Guida
# ...                                                ...               ...
# 74587                                       Ocean Hill   Justin Grossman
# 74588                                   Lincoln Square       Henry Daley
# 74589                               Claremont-Bathgate   John Villanueva
# 74590  Soundview-Castle Hill-Clason Point-Harding Park   Alfred Locascio
# 74591                                   West Concourse        Thomas Bia
#
# [67430 rows x 21 columns]

# %% [markdown]
# Eviction during covid stopped (https://hcr.ny.gov/covid-19-eviction-protections-tenants)

# %%
plt.figure(figsize=(10,5))
df.groupby(df['Executed Date'].dt.year)['Executed Date'].count() \
    .plot(kind='bar', color='#2E5984')
plt.xlabel('Year', size='14')
plt.ylabel('Amount of evictions', size='14')
plt.xticks(rotation=0, size='12')
plt.yticks(size='12')
plt.show()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'sans-serif' not found because none of the following families were found: Helvetica

# %%
df.groupby(df['Marshal Full Name'])['Executed Date'].count() \
    .sort_values(ascending=False) \
    .plot(kind='bar', color='#2E5984', figsize=(10,5), width=0.6)
plt.xlabel('Marshal', size='14')
plt.ylabel('Amount of evictions', size='14')
plt.xticks(rotation=90, size='12')
plt.yticks(size='12')
plt.show()

# %%
df.groupby(df['BOROUGH'])['Executed Date'].count() \
    .sort_values(ascending=False) \
    .plot(kind='bar', color='#2E5984', figsize=(8,5))
plt.xlabel('Borough', size='14')
plt.ylabel('Amount of evictions', size='14')
plt.xticks(rotation=0, size='12')
plt.yticks(size='12')
plt.show()

# %%
hous = pd.read_excel('housing_data/hous_2017_acs5yr_nta.xlsx')

# %%
hous
# Out:
#      GeoType                                            GeoName GeoID  \
# 0    NTA2010                            Allerton-Pelham Gardens  BX31
# 1    NTA2010                         Bedford Park-Fordham North  BX05
# 2    NTA2010                                            Belmont  BX06
# 3    NTA2010                                          Bronxdale  BX07
# 4    NTA2010                                 Claremont-Bathgate  BX01
# ..       ...                                                ...   ...
# 190  NTA2010                                  Rossville-Woodrow  SI32
# 191  NTA2010                                 Stapleton-Rosebank  SI37
# 192  NTA2010  Todt Hill-Emerson Hill-Heartland Village-Light...  SI24
# 193  NTA2010          West New Brighton-New Brighton-St. George  SI22
# 194  NTA2010                                        Westerleigh  SI07
#
#            Borough   HU1E   HU1M  HU1C   HU1P  HU1Z  OcHU1E  ...  GRPI50plE  \
# 0            Bronx   9983  134.0   0.8  100.0   NaN    9452  ...       1044
# 1            Bronx  20368  183.0   0.5  100.0   NaN   19329  ...       6081
# 2            Bronx   9757  142.0   0.9  100.0   NaN    9214  ...       3501
# 3            Bronx  14869  140.0   0.6  100.0   NaN   14143  ...       3455
# 4            Bronx  11524  100.0   0.5  100.0   NaN   10996  ...       3286
# ..             ...    ...    ...   ...    ...   ...     ...  ...        ...
# 190  Staten Island   7793  138.0   1.1  100.0   NaN    7586  ...        258
# 191  Staten Island  10570  180.0   1.0  100.0   NaN    9512  ...       1722
# 192  Staten Island  12159  164.0   0.8  100.0   NaN   11525  ...        805
# 193  Staten Island  13981  235.0   1.0  100.0   NaN   12155  ...       2208
# 194  Staten Island   9718  141.0   0.9  100.0   NaN    8966  ...        493
#
#      GRPI50plM  GRPI50plC  GRPI50plP  GRPI50plZ  GRPINtCE  GRPINtCM  GRPINtCC  \
# 0        216.0       12.6       27.8        5.3       269     118.0      26.6
# 1        483.0        4.8       34.3        2.6       683     204.0      18.2
# 2        366.0        6.3       42.4        4.1       519     177.0      20.7
# 3        371.0        6.5       30.3        3.1       513     166.0      19.7
# 4        361.0        6.7       32.1        3.5       340     124.0      22.2
# ..         ...        ...        ...        ...       ...       ...       ...
# 190      126.0       29.7       35.6       13.2       168     122.0      44.1
# 191      257.0        9.1       36.6        4.8       234     110.0      28.6
# 192      199.0       15.0       31.5        6.7       212     105.0      30.0
# 193      331.0        9.1       34.4        4.7       743     244.0      19.9
# 194      150.0       18.5       27.4        7.3       384     159.0      25.2
#
#      GRPINtCP  GRPINtCZ
# 0         NaN       NaN
# 1         NaN       NaN
# 2         NaN       NaN
# 3         NaN       NaN
# 4         NaN       NaN
# ..        ...       ...
# 190       NaN       NaN
# 191       NaN       NaN
# 192       NaN       NaN
# 193       NaN       NaN
# 194       NaN       NaN
#
# [195 rows x 524 columns]

# %%
nta_hous = hous['GeoName'].to_list()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3976\1956763041.py in <module>
# ----> 1 nta_hous = hous['GeoName'].to_list()
#
# TypeError: list indices must be integers or slices, not str

# %%
nta_df = df['NTA'].unique()

# %%
# see what NTA's are not in the list
missing = 0
for name in nta_df:
    if name not in nta_hous:
        missing += 1
        print(name)
# Out:
# Hudson Yards-Chelsea-Flatiron-Union Square

# %%
# lists spell name different
df.replace('Hudson Yards-Chelsea-Flatiron-Union Square','Hudson Yards-Chelsea-Flat Iron-Union Square')
# Out:
#       Court Index Number  Docket Number       Eviction Address  \
# 0               48174/18          349487   1238 BOYNTON AVENUE
# 1              B35706/18          108013  3235 GRAND CONCOURSE
# 2               55095/17           10840     640 E 86TH STREET
# 3              Q72651/16           75106     148-41 236 STREET
# 4               64094/17           11817     38-32 29TH STREET
# ...                  ...             ...                   ...
# 74587           87750/18           88027   2125 PACIFIC STREET
# 74588          315053/22          110298    315 WEST 61 STREET
# 74589           54940/16          320221  2277 BATHGATE AVENUE
# 74590           28486/19          172082       576 PUGSLEY AVE
# 74591           51564/16          328978    1240 WALTON AVENUE
#
#       Eviction Apartment Number Executed Date Marshal First Name  \
# 0                            1R    2019-03-08             Thomas
# 1                            6C    2018-10-03            Darlene
# 2                           NaN    2017-07-25             Edward
# 3                           NaN    2017-03-31             Ileana
# 4                             1    2017-08-16             Edward
# ...                         ...           ...                ...
# 74587                        4D    2019-10-07             Justin
# 74588                        8R    2023-02-22              Henry
# 74589                        5E    2017-05-02               John
# 74590                         1    2020-01-31             Alfred
# 74591                       406    2017-02-01             Thomas
#
#       Marshal Last Name Residential/Commercial    BOROUGH  Eviction Postcode  \
# 0                   Bia            Residential      BRONX              10472
# 1                Barone            Residential      BRONX              10468
# 2                 Guida            Residential   BROOKLYN              11236
# 3                Rivera            Residential     QUEENS              11422
# 4                 Guida            Residential     QUEENS              11101
# ...                 ...                    ...        ...                ...
# 74587          Grossman            Residential   BROOKLYN              11233
# 74588             Daley            Residential  MANHATTAN              10023
# 74589        Villanueva            Residential      BRONX              10457
# 74590          Locascio            Residential      BRONX              10473
# 74591               Bia            Residential      BRONX              10452
#
#        ... Eviction/Legal Possession   Latitude  Longitude  Community Board  \
# 0      ...                Possession  40.829759 -73.878482              9.0
# 1      ...                Possession  40.877488 -73.885258              7.0
# 2      ...                Possession  40.640733 -73.911547             18.0
# 3      ...                Possession  40.653782 -73.747053             13.0
# 4      ...                Possession  40.754198 -73.933916              1.0
# ...    ...                       ...        ...        ...              ...
# 74587  ...                Possession  40.675820 -73.916065             16.0
# 74588  ...                Possession  40.773086 -73.990057              7.0
# 74589  ...                Possession  40.854283 -73.892119              6.0
# 74590  ...                Possession  40.817854 -73.854034              9.0
# 74591  ...                Possession  40.835879 -73.918837              4.0
#
#        Council District  Census Tract        BIN           BBL  \
# 0                  18.0          54.0  2025234.0  2.037740e+09
# 1                  11.0         411.0  2017667.0  2.033230e+09
# 2                  46.0         958.0  3223963.0  3.079900e+09
# 3                  31.0         694.0  4443919.0  4.137360e+09
# 4                  26.0          31.0  4004669.0  4.003850e+09
# ...                 ...           ...        ...           ...
# 74587              41.0         303.0  3038558.0  3.014330e+09
# 74588               6.0         151.0  1087589.0  1.011718e+09
# 74589              15.0         385.0  2117654.0  2.030500e+09
# 74590              18.0          74.0  2088061.0  2.035330e+09
# 74591              16.0         197.0  2002852.0  2.024650e+09
#
#                                                    NTA Marshal Full Name
# 0                               West Farms-Bronx River        Thomas Bia
# 1                           Bedford Park-Fordham North    Darlene Barone
# 2                                             Canarsie      Edward Guida
# 3                 Springfield Gardens South-Brookville     Ileana Rivera
# 4             Queensbridge-Ravenswood-Long Island City      Edward Guida
# ...                                                ...               ...
# 74587                                       Ocean Hill   Justin Grossman
# 74588                                   Lincoln Square       Henry Daley
# 74589                               Claremont-Bathgate   John Villanueva
# 74590  Soundview-Castle Hill-Clason Point-Harding Park   Alfred Locascio
# 74591                                   West Concourse        Thomas Bia
#
# [67430 rows x 21 columns]

# %%
hous = ['hous_2017', 'hous_2018', 'hous_2019', 'hous_2020']
econ = ['econ_2017', 'econ_2018', 'econ_2019', 'econ_2020']
demo = ['demo_2017', 'demo_2018', 'demo_2019', 'demo_2020']
soc = ['soc_2017', 'soc_2018', 'soc_2019', 'soc_2020']

number = 1
for i in range(len(data)):
    d = pd.read_csv('Data/Data' + str(i) + '.tsv', sep='\t', header=None, names=columns)
    myVars = locals()
    myVars.__setitem__(data[j], d)
    i += 1
    
data = [data1, data2, data3, data4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3976\175315193.py in <module>
#       5
#       6 number = 1
# ----> 7 for i in range(len(data)):
#       8     d = pd.read_csv('Data/Data' + str(i) + '.tsv', sep='\t', header=None, names=columns)
#       9     myVars = locals()
#
# NameError: name 'data' is not defined

# %%
hous['MdGRE'].plot(bins=30, kind='hist', figsize=(15,7), color='#2E5984', rwidth=0.8)
plt.xlabel('Average rent in NYC', size=12)
plt.ylabel('Frequency', size=12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3976\226849770.py in <module>
# ----> 1 hous['MdGRE'].plot(bins=30, kind='hist', figsize=(15,7), color='#2E5984', rwidth=0.8)
#       2 plt.xlabel('Average rent in NYC', size=12)
#       3 plt.ylabel('Frequency', size=12)
#       4 plt.show()
#
# TypeError: list indices must be integers or slices, not str
